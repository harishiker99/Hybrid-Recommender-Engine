# %% [markdown]
# This notebook is used to prepare the dataset that will be used for the job recommender chatbot. The initial dataset of LinkedIn Job Postings - 2023 (job_postings.csv) from https://www.kaggle.com/datasets/arshkon/linkedin-job-postings has numerous industries, job titles, locations (ALL IN USA), etc. We will limit the number of industries and job titles just for the purpose of simplified chatbot implementation.

# %% [markdown]
# # **Import Needed Libraries**

# %%
# Import needed libraries
import numpy as np # for linear algebra
import pandas as pd # for loading data from csv file and data processing
import matplotlib.pyplot as plt # to plot figures
import re

# %% [markdown]
# # **Upload Dataset**

# %%
job_to_industry = pd.read_csv("/content/job_industries.csv")

# %%
industry_name = pd.read_csv("/content/industries.csv")

# %%
df= pd.read_csv("/content/job_postings.csv")
df
# Out:
#            job_id  company_id  \
# 0      3757940104    553718.0
# 1      3757940025   2192142.0
# 2      3757938019    474443.0
# 3      3757938018  18213359.0
# 4      3757937095    437225.0
# ...           ...         ...
# 33241   133114754  77766802.0
# 33242   108965123         NaN
# 33243   102339515  52132271.0
# 33244    85008768         NaN
# 33245     3958427    630152.0
#
#                                                    title  \
# 0                                  Hearing Care Provider
# 1      Shipping & Receiving Associate 2nd shift (Beav...
# 2                                   Manager, Engineering
# 3                                                   Cook
# 4            Principal Cloud Security Architect (Remote)
# ...                                                  ...
# 33241                                      Sales Manager
# 33242                    Office Administrative Assistant
# 33243                                    Franchise Owner
# 33244                           Licensed Insurance Agent
# 33245                                   Stylist/ Clorist
#
#                                              description  max_salary  \
# 0      Overview\n\nHearingLife is a national hearing ...         NaN
# 1      Metalcraft of Mayville\nMetalcraft of Mayville...         NaN
# 2      \nThe TSUBAKI name is synonymous with excellen...         NaN
# 3      descriptionTitle\n\n Looking for a great oppor...         NaN
# 4      Job Summary\nAt iHerb, we are on a mission to ...    275834.0
# ...                                                  ...         ...
# 33241  Are you a dynamic and creative marketing profe...         NaN
# 33242  A fast-fashion wholesaler, is looking for a fu...         NaN
# 33243  DuctVentz is a dryer and A/C – heat vent clean...         NaN
# 33244  While many industries were hurt by the last fe...     52000.0
# 33245  Karen Marie is looking for an awesome experien...     80000.0
#
#        med_salary  min_salary pay_period formatted_work_type  \
# 0         5250.00         NaN    MONTHLY           Full-time
# 1             NaN         NaN        NaN           Full-time
# 2             NaN         NaN        NaN           Full-time
# 3           22.27         NaN     HOURLY           Full-time
# 4             NaN    205956.0     YEARLY           Full-time
# ...           ...         ...        ...                 ...
# 33241         NaN         NaN        NaN           Full-time
# 33242         NaN         NaN        NaN           Full-time
# 33243         NaN         NaN        NaN           Full-time
# 33244         NaN     45760.0     YEARLY           Full-time
# 33245         NaN     35000.0     YEARLY           Full-time
#
#                 location  ...  closed_time  formatted_experience_level  \
# 0       Little River, SC  ...          NaN                 Entry level
# 1         Beaver Dam, WI  ...          NaN                         NaN
# 2           Bessemer, AL  ...          NaN                         NaN
# 3        Aliso Viejo, CA  ...          NaN                 Entry level
# 4          United States  ...          NaN            Mid-Senior level
# ...                  ...  ...          ...                         ...
# 33241  Santa Clarita, CA  ...          NaN                         NaN
# 33242       New York, NY  ...          NaN                         NaN
# 33243     Greater Boston  ...          NaN                         NaN
# 33244          Chico, CA  ...          NaN                         NaN
# 33245        Chicago, IL  ...          NaN                         NaN
#
#                                              skills_desc   listed_time  \
# 0                                                    NaN  1.699090e+12
# 1                                                    NaN  1.699080e+12
# 2      Bachelor's Degree in Mechanical Engineering pr...  1.699080e+12
# 3                                                    NaN  1.699080e+12
# 4                                                    NaN  1.699090e+12
# ...                                                  ...           ...
# 33241                                                NaN  1.692830e+12
# 33242                                                NaN  1.699040e+12
# 33243                                                NaN  1.699050e+12
# 33244                                                NaN  1.692750e+12
# 33245  Must be a seasoned stylist with an existing bo...  1.699050e+12
#
#                  posting_domain sponsored  work_type  currency  \
# 0      careers-demant.icims.com         0  FULL_TIME       USD
# 1           www.click2apply.net         0  FULL_TIME       NaN
# 2           www.click2apply.net         0  FULL_TIME       NaN
# 3               jobs.apploi.com         0  FULL_TIME       USD
# 4             careers.iherb.com         0  FULL_TIME       USD
# ...                         ...       ...        ...       ...
# 33241                       NaN         0  FULL_TIME       NaN
# 33242                       NaN         0  FULL_TIME       NaN
# 33243                       NaN         0  FULL_TIME       NaN
# 33244                       NaN         1  FULL_TIME       USD
# 33245                       NaN         0  FULL_TIME       USD
#
#        compensation_type     scraped
# 0            BASE_SALARY  1699138101
# 1                    NaN  1699085420
# 2                    NaN  1699085644
# 3            BASE_SALARY  1699087461
# 4            BASE_SALARY  1699085346
# ...                  ...         ...
# 33241                NaN           1
# 33242                NaN  1699044401
# 33243                NaN  1699063495
# 33244        BASE_SALARY           1
# 33245        BASE_SALARY  1699057868
#
# [33246 rows x 28 columns]

# %%
df.columns
# Out:
# Index(['job_id', 'company_id', 'title', 'description', 'max_salary',
#        'med_salary', 'min_salary', 'pay_period', 'formatted_work_type',
#        'location', 'applies', 'original_listed_time', 'remote_allowed',
#        'views', 'job_posting_url', 'application_url', 'application_type',
#        'expiry', 'closed_time', 'formatted_experience_level', 'skills_desc',
#        'listed_time', 'posting_domain', 'sponsored', 'work_type', 'currency',
#        'compensation_type', 'scraped'],
#       dtype='object')

# %% [markdown]
# # **Drop unnecessary columns**

# %% [markdown]
# We will drop the columns which are not relevant to the job recommendation task and which don't provide useful information for the clustering and classification of jobs.

# %%
df = df.drop(['company_id', 'max_salary',
       'med_salary', 'min_salary', 'pay_period', 'applies', 'original_listed_time', 'remote_allowed',
       'views','application_url', 'application_type',
       'expiry', 'closed_time',
       'listed_time', 'posting_domain', 'sponsored', 'currency',
       'compensation_type', 'scraped', 'skills_desc', 'work_type'],axis='columns')
df
# Out:
#            job_id                                              title  \
# 0      3757940104                              Hearing Care Provider
# 1      3757940025  Shipping & Receiving Associate 2nd shift (Beav...
# 2      3757938019                               Manager, Engineering
# 3      3757938018                                               Cook
# 4      3757937095        Principal Cloud Security Architect (Remote)
# ...           ...                                                ...
# 33241   133114754                                      Sales Manager
# 33242   108965123                    Office Administrative Assistant
# 33243   102339515                                    Franchise Owner
# 33244    85008768                           Licensed Insurance Agent
# 33245     3958427                                   Stylist/ Clorist
#
#                                              description formatted_work_type  \
# 0      Overview\n\nHearingLife is a national hearing ...           Full-time
# 1      Metalcraft of Mayville\nMetalcraft of Mayville...           Full-time
# 2      \nThe TSUBAKI name is synonymous with excellen...           Full-time
# 3      descriptionTitle\n\n Looking for a great oppor...           Full-time
# 4      Job Summary\nAt iHerb, we are on a mission to ...           Full-time
# ...                                                  ...                 ...
# 33241  Are you a dynamic and creative marketing profe...           Full-time
# 33242  A fast-fashion wholesaler, is looking for a fu...           Full-time
# 33243  DuctVentz is a dryer and A/C – heat vent clean...           Full-time
# 33244  While many industries were hurt by the last fe...           Full-time
# 33245  Karen Marie is looking for an awesome experien...           Full-time
#
#                 location                                    job_posting_url  \
# 0       Little River, SC  https://www.linkedin.com/jobs/view/3757940104/...
# 1         Beaver Dam, WI  https://www.linkedin.com/jobs/view/3757940025/...
# 2           Bessemer, AL  https://www.linkedin.com/jobs/view/3757938019/...
# 3        Aliso Viejo, CA  https://www.linkedin.com/jobs/view/3757938018/...
# 4          United States  https://www.linkedin.com/jobs/view/3757937095/...
# ...                  ...                                                ...
# 33241  Santa Clarita, CA  https://www.linkedin.com/jobs/view/133114754/?...
# 33242       New York, NY  https://www.linkedin.com/jobs/view/108965123/?...
# 33243     Greater Boston  https://www.linkedin.com/jobs/view/102339515/?...
# 33244          Chico, CA  https://www.linkedin.com/jobs/view/85008768/?t...
# 33245        Chicago, IL  https://www.linkedin.com/jobs/view/3958427/?tr...
#
#       formatted_experience_level
# 0                    Entry level
# 1                            NaN
# 2                            NaN
# 3                    Entry level
# 4               Mid-Senior level
# ...                          ...
# 33241                        NaN
# 33242                        NaN
# 33243                        NaN
# 33244                        NaN
# 33245                        NaN
#
# [33246 rows x 7 columns]

# %%
df.columns
# Out:
# Index(['job_id', 'title', 'description', 'formatted_work_type', 'location',
#        'job_posting_url', 'formatted_experience_level'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33246 entries, 0 to 33245
# Data columns (total 7 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   job_id                      33246 non-null  int64
#  1   title                       33246 non-null  object
#  2   description                 33245 non-null  object
#  3   formatted_work_type         33246 non-null  object
#  4   location                    33246 non-null  object
#  5   job_posting_url             33246 non-null  object
#  6   formatted_experience_level  24065 non-null  object
# dtypes: int64(1), object(6)
# memory usage: 1.8+ MB

# %% [markdown]
# # **Drop Missing Values**

# %%
# Drop entries with missing values for the narrative attribute
df= df.dropna()
# Rearrange indices to be of the form 0, 1, …, n - 1.
df= df.reset_index(drop=True)
df
# Out:
#            job_id                                              title  \
# 0      3757940104                              Hearing Care Provider
# 1      3757938018                                               Cook
# 2      3757937095        Principal Cloud Security Architect (Remote)
# 3      3757937037                      Territory Manager - New Haven
# 4      3757937004                                Auto Body Techncian
# ...           ...                                                ...
# 24060  2148434077  Transporter - Full Time Evenings 3pm-11pm; Rot...
# 24061  2148434033                       Contract Bilingual Recruiter
# 24062  2148434032                                        Tax Analyst
# 24063  2148434019  Virtual Sales Associate Account Manager, Women...
# 24064  2148434014  Virtual Sales Associate Account Manager, Women...
#
#                                              description formatted_work_type  \
# 0      Overview\n\nHearingLife is a national hearing ...           Full-time
# 1      descriptionTitle\n\n Looking for a great oppor...           Full-time
# 2      Job Summary\nAt iHerb, we are on a mission to ...           Full-time
# 3      Location: Remote, CT, United States of America...           Full-time
# 4      Company: Gerber Collision & Glass\n\nWELCOME T...           Full-time
# ...                                                  ...                 ...
# 24060  Service / Ancillary Staff --> Housekeeping\nPa...           Full-time
# 24061  Location: Phoenix, AZ 85006---- IN OFFICE JOB ...            Contract
# 24062  RaceTrac Company Overview\n\nJob Description:\...           Full-time
# 24063  Job Description Summary \n\nAs the Virtual Sal...           Full-time
# 24064  Job Description Summary \n\nAs the Virtual Sal...           Full-time
#
#                          location  \
# 0                Little River, SC
# 1                 Aliso Viejo, CA
# 2                   United States
# 3                   United States
# 4               Daytona Beach, FL
# ...                           ...
# 24060               Patchogue, NY
# 24061                 Phoenix, AZ
# 24062                 Atlanta, GA
# 24063  Connecticut, United States
# 24064        Maine, United States
#
#                                          job_posting_url  \
# 0      https://www.linkedin.com/jobs/view/3757940104/...
# 1      https://www.linkedin.com/jobs/view/3757938018/...
# 2      https://www.linkedin.com/jobs/view/3757937095/...
# 3      https://www.linkedin.com/jobs/view/3757937037/...
# 4      https://www.linkedin.com/jobs/view/3757937004/...
# ...                                                  ...
# 24060  https://www.linkedin.com/jobs/view/2148434077/...
# 24061  https://www.linkedin.com/jobs/view/2148434033/...
# 24062  https://www.linkedin.com/jobs/view/2148434032/...
# 24063  https://www.linkedin.com/jobs/view/2148434019/...
# 24064  https://www.linkedin.com/jobs/view/2148434014/...
#
#       formatted_experience_level
# 0                    Entry level
# 1                    Entry level
# 2               Mid-Senior level
# 3               Mid-Senior level
# 4                    Entry level
# ...                          ...
# 24060                Entry level
# 24061                  Associate
# 24062                Entry level
# 24063                Entry level
# 24064                Entry level
#
# [24065 rows x 7 columns]

# %% [markdown]
# # **Map industry_id to industry names**

# %%
industry_id = []
for job in df['job_id']:
  industry_id.append(job_to_industry[job_to_industry['job_id']==job]['industry_id'].values[0])

# %%
industry_names = []
for id in industry_id:
  industry_names.append(industry_name[industry_name['industry_id']==id]['industry_name'].values[0])

# %%
df['industry']= industry_names

# %% [markdown]
# **NOTE: THIS INDUSTRY LABEL WILL NOT BE USED LATER ON. INDUSTRIES WILL BE REDEFINED BASED ON CHOSEN JOB TITLES.**

# %% [markdown]
# # **Map formatted_experience_level values to Beginner, Intermediate, and Senior**

# %%
df.loc[(df['formatted_experience_level']=='Entry level')|(df['formatted_experience_level']=='Internship'),'formatted_experience_level']='Beginner'
df.loc[(df['formatted_experience_level']=='Associate'),'formatted_experience_level']='Intermediate'
df.loc[(df['formatted_experience_level']=='Mid-Senior level')|(df['formatted_experience_level']=='Director')|(df['formatted_experience_level']=='Executive'),'formatted_experience_level']='Senior'

# %% [markdown]
# # **Drop jobs with unknown work type**

# %%
df = df.drop(df[df['formatted_work_type']=='Other'].index)
df= df.reset_index(drop=True)
df
# Out:
#            job_id                                              title  \
# 0      3757940104                              Hearing Care Provider
# 1      3757938018                                               Cook
# 2      3757937095        Principal Cloud Security Architect (Remote)
# 3      3757937037                      Territory Manager - New Haven
# 4      3757937004                                Auto Body Techncian
# ...           ...                                                ...
# 24005  2148434077  Transporter - Full Time Evenings 3pm-11pm; Rot...
# 24006  2148434033                       Contract Bilingual Recruiter
# 24007  2148434032                                        Tax Analyst
# 24008  2148434019  Virtual Sales Associate Account Manager, Women...
# 24009  2148434014  Virtual Sales Associate Account Manager, Women...
#
#                                              description formatted_work_type  \
# 0      Overview\n\nHearingLife is a national hearing ...           Full-time
# 1      descriptionTitle\n\n Looking for a great oppor...           Full-time
# 2      Job Summary\nAt iHerb, we are on a mission to ...           Full-time
# 3      Location: Remote, CT, United States of America...           Full-time
# 4      Company: Gerber Collision & Glass\n\nWELCOME T...           Full-time
# ...                                                  ...                 ...
# 24005  Service / Ancillary Staff --> Housekeeping\nPa...           Full-time
# 24006  Location: Phoenix, AZ 85006---- IN OFFICE JOB ...            Contract
# 24007  RaceTrac Company Overview\n\nJob Description:\...           Full-time
# 24008  Job Description Summary \n\nAs the Virtual Sal...           Full-time
# 24009  Job Description Summary \n\nAs the Virtual Sal...           Full-time
#
#                          location  \
# 0                Little River, SC
# 1                 Aliso Viejo, CA
# 2                   United States
# 3                   United States
# 4               Daytona Beach, FL
# ...                           ...
# 24005               Patchogue, NY
# 24006                 Phoenix, AZ
# 24007                 Atlanta, GA
# 24008  Connecticut, United States
# 24009        Maine, United States
#
#                                          job_posting_url  \
# 0      https://www.linkedin.com/jobs/view/3757940104/...
# 1      https://www.linkedin.com/jobs/view/3757938018/...
# 2      https://www.linkedin.com/jobs/view/3757937095/...
# 3      https://www.linkedin.com/jobs/view/3757937037/...
# 4      https://www.linkedin.com/jobs/view/3757937004/...
# ...                                                  ...
# 24005  https://www.linkedin.com/jobs/view/2148434077/...
# 24006  https://www.linkedin.com/jobs/view/2148434033/...
# 24007  https://www.linkedin.com/jobs/view/2148434032/...
# 24008  https://www.linkedin.com/jobs/view/2148434019/...
# 24009  https://www.linkedin.com/jobs/view/2148434014/...
#
#       formatted_experience_level                         industry
# 0                       Beginner  Medical Equipment Manufacturing
# 1                       Beginner         Non-profit Organizations
# 2                         Senior                           Retail
# 3                         Senior  Medical Equipment Manufacturing
# 4                       Beginner                       Automotive
# ...                          ...                              ...
# 24005                   Beginner        Hospitals and Health Care
# 24006               Intermediate                       Accounting
# 24007                   Beginner                           Retail
# 24008                   Beginner        Hospitals and Health Care
# 24009                   Beginner        Hospitals and Health Care
#
# [24010 rows x 8 columns]

# %% [markdown]
# # **Drop jobs that don't mention the specific US state**

# %%
df = df.drop(df[df['location']=='United States'].index)
df= df.reset_index(drop=True)
df
# Out:
#            job_id                                              title  \
# 0      3757940104                              Hearing Care Provider
# 1      3757938018                                               Cook
# 2      3757937004                                Auto Body Techncian
# 3      3757936167      ACME D8- Asst Store Director (ASD) Sussex, NJ
# 4      3757936097                                         Dishwasher
# ...           ...                                                ...
# 22598  2148434077  Transporter - Full Time Evenings 3pm-11pm; Rot...
# 22599  2148434033                       Contract Bilingual Recruiter
# 22600  2148434032                                        Tax Analyst
# 22601  2148434019  Virtual Sales Associate Account Manager, Women...
# 22602  2148434014  Virtual Sales Associate Account Manager, Women...
#
#                                              description formatted_work_type  \
# 0      Overview\n\nHearingLife is a national hearing ...           Full-time
# 1      descriptionTitle\n\n Looking for a great oppor...           Full-time
# 2      Company: Gerber Collision & Glass\n\nWELCOME T...           Full-time
# 3      The First Assistant Store Director is actively...           Full-time
# 4      descriptionTitle\n\n $2,000 Sign-on Bonus Guar...           Full-time
# ...                                                  ...                 ...
# 22598  Service / Ancillary Staff --> Housekeeping\nPa...           Full-time
# 22599  Location: Phoenix, AZ 85006---- IN OFFICE JOB ...            Contract
# 22600  RaceTrac Company Overview\n\nJob Description:\...           Full-time
# 22601  Job Description Summary \n\nAs the Virtual Sal...           Full-time
# 22602  Job Description Summary \n\nAs the Virtual Sal...           Full-time
#
#                          location  \
# 0                Little River, SC
# 1                 Aliso Viejo, CA
# 2               Daytona Beach, FL
# 3                      Sussex, NJ
# 4                 Aliso Viejo, CA
# ...                           ...
# 22598               Patchogue, NY
# 22599                 Phoenix, AZ
# 22600                 Atlanta, GA
# 22601  Connecticut, United States
# 22602        Maine, United States
#
#                                          job_posting_url  \
# 0      https://www.linkedin.com/jobs/view/3757940104/...
# 1      https://www.linkedin.com/jobs/view/3757938018/...
# 2      https://www.linkedin.com/jobs/view/3757937004/...
# 3      https://www.linkedin.com/jobs/view/3757936167/...
# 4      https://www.linkedin.com/jobs/view/3757936097/...
# ...                                                  ...
# 22598  https://www.linkedin.com/jobs/view/2148434077/...
# 22599  https://www.linkedin.com/jobs/view/2148434033/...
# 22600  https://www.linkedin.com/jobs/view/2148434032/...
# 22601  https://www.linkedin.com/jobs/view/2148434019/...
# 22602  https://www.linkedin.com/jobs/view/2148434014/...
#
#       formatted_experience_level                         industry
# 0                       Beginner  Medical Equipment Manufacturing
# 1                       Beginner         Non-profit Organizations
# 2                       Beginner                       Automotive
# 3                         Senior                           Retail
# 4                       Beginner         Non-profit Organizations
# ...                          ...                              ...
# 22598                   Beginner        Hospitals and Health Care
# 22599               Intermediate                       Accounting
# 22600                   Beginner                           Retail
# 22601                   Beginner        Hospitals and Health Care
# 22602                   Beginner        Hospitals and Health Care
#
# [22603 rows x 8 columns]

# %% [markdown]
# # **Rename similar job titles**

# %% [markdown]
# We renamed similar job for easier chatbot implementation so that it aligns with Dialogflow.

# %%
df.loc[df['title'].apply(lambda x: ('Data Engineer' in x)|('Data Developer' in x)),'title']='Data Engineer'

# %%
df.loc[df['title'].apply(lambda x: ('Data Scientist' in x)|('Data Analy' in x)|('Data Architect' in x)),'title']='Data Scientist'

# %%
df.loc[df['title'].apply(lambda x: 'Database' in x),'title']='Database Management'

# %%
df.loc[df['title'].apply(lambda x: 'Developer' in x),'title']='Developer'

# %%
df.loc[df['title'].apply(lambda x: ('UI' in x)|('UX' in x)),'title']='UI/UX Designer'

# %%
df.loc[df['title'].apply(lambda x: ('Software Engineer' in x)),'title']='Software Engineer'

# %%
df.loc[df['title'].apply(lambda x: ('Nurse' in x)),'title']='Nurse'

# %%
df.loc[df['title'].apply(lambda x: ('Nursing Assistant' in x)),'title']='Nursing Assistant'

# %%
df.loc[df['title'].apply(lambda x: ('Veterinarian' in x)),'title']='Veterinarian'

# %%
df.loc[df['title'].apply(lambda x: ('Veterinary Assistant' in x)),'title']='Veterinary Assistant'

# %%
df.loc[df['title'].apply(lambda x: ('Veterinary Technician' in x)),'title']='Veterinary Technician'

# %%
df.loc[df['title'].apply(lambda x: ('Dental Assistant' in x)),'title']='Dental Assistant'

# %%
df.loc[df['title'].apply(lambda x: ('Dental Hygienist' in x)),'title']='Dental Hygienist'

# %%
df.loc[df['title'].apply(lambda x: ('Dentist' in x)),'title']='Dentist'

# %%
df.loc[df['title'].apply(lambda x: ('Account Executive' in x)),'title']='Account Executive'

# %%
df.loc[df['title'].apply(lambda x: ('Portfolio Manag' in x)),'title']='Portfolio Manager'

# %%
df.loc[df['title'].apply(lambda x: ('Financial Analyst' in x)),'title']='Financial Analyst'

# %%
df.loc[df['title'].apply(lambda x: ('Banker' in x)),'title']='Banker'

# %%
df.loc[df['title'].apply(lambda x: ('Accountant' in x)),'title']='Accountant'

# %%
df.loc[df['title'].apply(lambda x: ('Tax' in x)),'title']='Tax Professional'

# %%
df.loc[df['title'].apply(lambda x: ('Retirement' in x)),'title']='Retirement Specialist'

# %% [markdown]
# # **Choose a couple of job titles for each of the 3 industries: IT, Healthcare, Finance**

# %%
IT_list = ['Data Engineer','Data Scientist','Database Management','Developer','UI/UX Designer','Software Engineer']
Healthcare_list = ['Nurse','Nursing Assistant','Veterinarian','Veterinary Assistant','Veterinary Technician','Dental Assistant','Dental Hygienist','Dentist']
Finance_list = ['Account Executive','Portfolio Manager','Financial Analyst','Retirement Specialist','Banker','Accountant','Tax Professional']

# %%
all_titles = IT_list + Healthcare_list + Finance_list

# %%
df = df[df['title'].isin(all_titles)]

# %%
df= df.reset_index(drop=True)
df
# Out:
#           job_id              title  \
# 0     3757935025       Veterinarian
# 1     3757934327       Veterinarian
# 2     3757933458       Veterinarian
# 3     3757932826       Veterinarian
# 4     3757931806       Veterinarian
# ...          ...                ...
# 2649  3684441939         Accountant
# 2650  3682818140          Developer
# 2651  3663878663         Accountant
# 2652  3584068782  Account Executive
# 2653  2148434032   Tax Professional
#
#                                             description formatted_work_type  \
# 0     We are looking to hire an Associate Veterinari...           Full-time
# 1     We are looking to hire an Associate Veterinari...           Full-time
# 2     We are looking to hire an Associate Veterinari...           Full-time
# 3     We are looking to hire an Associate Veterinari...           Full-time
# 4     We are looking to hire an Associate Veterinari...           Full-time
# ...                                                 ...                 ...
# 2649  Titus Talent Strategies has partnered with SAR...           Full-time
# 2650  Carefully read the JD before applying!Job Desc...            Contract
# 2651  Bring YOUR energy to Alliant Energy!\n\nAt All...           Full-time
# 2652  Position SummaryThe Account Executive role foc...           Full-time
# 2653  RaceTrac Company Overview\n\nJob Description:\...           Full-time
#
#                                       location  \
# 0     St Clair Shores, Michigan, United States
# 1                                   Denver, CO
# 2                               Santa Rosa, CA
# 3                               Pittsburgh, PA
# 4                                 Syracuse, NY
# ...                                        ...
# 2649                               Madison, WI
# 2650                              McKinney, TX
# 2651                               Madison, WI
# 2652                    San Francisco Bay Area
# 2653                               Atlanta, GA
#
#                                         job_posting_url  \
# 0     https://www.linkedin.com/jobs/view/3757935025/...
# 1     https://www.linkedin.com/jobs/view/3757934327/...
# 2     https://www.linkedin.com/jobs/view/3757933458/...
# 3     https://www.linkedin.com/jobs/view/3757932826/...
# 4     https://www.linkedin.com/jobs/view/3757931806/...
# ...                                                 ...
# 2649  https://www.linkedin.com/jobs/view/3684441939/...
# 2650  https://www.linkedin.com/jobs/view/3682818140/...
# 2651  https://www.linkedin.com/jobs/view/3663878663/...
# 2652  https://www.linkedin.com/jobs/view/3584068782/...
# 2653  https://www.linkedin.com/jobs/view/2148434032/...
#
#      formatted_experience_level                             industry
# 0                        Senior                  Veterinary Services
# 1                        Senior                  Veterinary Services
# 2                        Senior                  Veterinary Services
# 3                        Senior                  Veterinary Services
# 4                        Senior                  Veterinary Services
# ...                         ...                                  ...
# 2649                   Beginner  Leasing Non-residential Real Estate
# 2650                     Senior                            Insurance
# 2651                   Beginner                            Utilities
# 2652                     Senior                       Legal Services
# 2653                   Beginner                               Retail
#
# [2654 rows x 8 columns]

# %% [markdown]
# # **Redefine industry column**

# %%
df.loc[df['title'].isin(IT_list),'industry']='IT'

# %%
df.loc[df['title'].isin(Healthcare_list),'industry']='Healthcare'

# %%
df.loc[df['title'].isin(Finance_list),'industry']='Finance'

# %%
df
# Out:
#           job_id              title  \
# 0     3757935025       Veterinarian
# 1     3757934327       Veterinarian
# 2     3757933458       Veterinarian
# 3     3757932826       Veterinarian
# 4     3757931806       Veterinarian
# ...          ...                ...
# 2649  3684441939         Accountant
# 2650  3682818140          Developer
# 2651  3663878663         Accountant
# 2652  3584068782  Account Executive
# 2653  2148434032   Tax Professional
#
#                                             description formatted_work_type  \
# 0     We are looking to hire an Associate Veterinari...           Full-time
# 1     We are looking to hire an Associate Veterinari...           Full-time
# 2     We are looking to hire an Associate Veterinari...           Full-time
# 3     We are looking to hire an Associate Veterinari...           Full-time
# 4     We are looking to hire an Associate Veterinari...           Full-time
# ...                                                 ...                 ...
# 2649  Titus Talent Strategies has partnered with SAR...           Full-time
# 2650  Carefully read the JD before applying!Job Desc...            Contract
# 2651  Bring YOUR energy to Alliant Energy!\n\nAt All...           Full-time
# 2652  Position SummaryThe Account Executive role foc...           Full-time
# 2653  RaceTrac Company Overview\n\nJob Description:\...           Full-time
#
#                                       location  \
# 0     St Clair Shores, Michigan, United States
# 1                                   Denver, CO
# 2                               Santa Rosa, CA
# 3                               Pittsburgh, PA
# 4                                 Syracuse, NY
# ...                                        ...
# 2649                               Madison, WI
# 2650                              McKinney, TX
# 2651                               Madison, WI
# 2652                    San Francisco Bay Area
# 2653                               Atlanta, GA
#
#                                         job_posting_url  \
# 0     https://www.linkedin.com/jobs/view/3757935025/...
# 1     https://www.linkedin.com/jobs/view/3757934327/...
# 2     https://www.linkedin.com/jobs/view/3757933458/...
# 3     https://www.linkedin.com/jobs/view/3757932826/...
# 4     https://www.linkedin.com/jobs/view/3757931806/...
# ...                                                 ...
# 2649  https://www.linkedin.com/jobs/view/3684441939/...
# 2650  https://www.linkedin.com/jobs/view/3682818140/...
# 2651  https://www.linkedin.com/jobs/view/3663878663/...
# 2652  https://www.linkedin.com/jobs/view/3584068782/...
# 2653  https://www.linkedin.com/jobs/view/2148434032/...
#
#      formatted_experience_level    industry
# 0                        Senior  Healthcare
# 1                        Senior  Healthcare
# 2                        Senior  Healthcare
# 3                        Senior  Healthcare
# 4                        Senior  Healthcare
# ...                         ...         ...
# 2649                   Beginner     Finance
# 2650                     Senior          IT
# 2651                   Beginner     Finance
# 2652                     Senior     Finance
# 2653                   Beginner     Finance
#
# [2654 rows x 8 columns]

# %% [markdown]
# # **Convert abbreviated state names in location column to full state name**

# %%
abbreviated_states = [
    "AL", "AK", "AZ", "AR", "CA", "CO", "CT", "DE", "FL", "GA",
    "HI", "ID", "IL", "IN", "IA", "KS", "KY", "LA", "ME", "MD",
    "MA", "MI", "MN", "MS", "MO", "MT", "NE", "NV", "NH", "NJ",
    "NM", "NY", "NC", "ND", "OH", "OK", "OR", "PA", "RI", "SC",
    "SD", "TN", "TX", "UT", "VT", "VA", "WA", "WV", "WI", "WY"
]

state_names = [
    "Alabama", "Alaska", "Arizona", "Arkansas", "California",
    "Colorado", "Connecticut", "Delaware", "Florida", "Georgia",
    "Hawaii", "Idaho", "Illinois", "Indiana", "Iowa", "Kansas",
    "Kentucky", "Louisiana", "Maine", "Maryland",
    "Massachusetts", "Michigan", "Minnesota", "Mississippi",
    "Missouri", "Montana", "Nebraska", "Nevada", "New Hampshire",
    "New Jersey", "New Mexico", "New York", "North Carolina",
    "North Dakota", "Ohio", "Oklahoma", "Oregon", "Pennsylvania",
    "Rhode Island", "South Carolina", "South Dakota", "Tennessee",
    "Texas", "Utah", "Vermont", "Virginia", "Washington",
    "West Virginia", "Wisconsin", "Wyoming"
]

for state, abb in zip(state_names, abbreviated_states):
  df.loc[df['location'].apply(lambda x: (state in x)|(abb in x)),'location']=state

# %%
df=df[df['location'].isin(state_names)]
df= df.reset_index(drop=True)
df
# Out:
#           job_id              title  \
# 0     3757935025       Veterinarian
# 1     3757934327       Veterinarian
# 2     3757933458       Veterinarian
# 3     3757932826       Veterinarian
# 4     3757931806       Veterinarian
# ...          ...                ...
# 2574  3685418185  Software Engineer
# 2575  3684441939         Accountant
# 2576  3682818140          Developer
# 2577  3663878663         Accountant
# 2578  2148434032   Tax Professional
#
#                                             description formatted_work_type  \
# 0     We are looking to hire an Associate Veterinari...           Full-time
# 1     We are looking to hire an Associate Veterinari...           Full-time
# 2     We are looking to hire an Associate Veterinari...           Full-time
# 3     We are looking to hire an Associate Veterinari...           Full-time
# 4     We are looking to hire an Associate Veterinari...           Full-time
# ...                                                 ...                 ...
# 2574  Who we are:Founded in 2017, Gatik is the leade...           Full-time
# 2575  Titus Talent Strategies has partnered with SAR...           Full-time
# 2576  Carefully read the JD before applying!Job Desc...            Contract
# 2577  Bring YOUR energy to Alliant Energy!\n\nAt All...           Full-time
# 2578  RaceTrac Company Overview\n\nJob Description:\...           Full-time
#
#           location                                    job_posting_url  \
# 0         Michigan  https://www.linkedin.com/jobs/view/3757935025/...
# 1         Colorado  https://www.linkedin.com/jobs/view/3757934327/...
# 2       California  https://www.linkedin.com/jobs/view/3757933458/...
# 3     Pennsylvania  https://www.linkedin.com/jobs/view/3757932826/...
# 4         New York  https://www.linkedin.com/jobs/view/3757931806/...
# ...            ...                                                ...
# 2574    California  https://www.linkedin.com/jobs/view/3685418185/...
# 2575     Wisconsin  https://www.linkedin.com/jobs/view/3684441939/...
# 2576         Texas  https://www.linkedin.com/jobs/view/3682818140/...
# 2577     Wisconsin  https://www.linkedin.com/jobs/view/3663878663/...
# 2578       Georgia  https://www.linkedin.com/jobs/view/2148434032/...
#
#      formatted_experience_level    industry
# 0                        Senior  Healthcare
# 1                        Senior  Healthcare
# 2                        Senior  Healthcare
# 3                        Senior  Healthcare
# 4                        Senior  Healthcare
# ...                         ...         ...
# 2574                     Senior          IT
# 2575                   Beginner     Finance
# 2576                     Senior          IT
# 2577                   Beginner     Finance
# 2578                   Beginner     Finance
#
# [2579 rows x 8 columns]

# %% [markdown]
# # **Exploration of obtained dataset after preprocessing**

# %%
df.columns
# Out:
# Index(['job_id', 'title', 'description', 'formatted_work_type', 'location',
#        'job_posting_url', 'formatted_experience_level', 'industry'],
#       dtype='object')

# %% [markdown]
# ## **Distribution of industry in obtained dataset**

# %%
df['industry'].value_counts()
# Out:
# Healthcare    1008
# Finance        812
# IT             759
# Name: industry, dtype: int64

# %% [markdown]
# ## **Distribution of job titles in obtained data set**

# %%
df['title'].value_counts()
# Out:
# Nurse                    817
# Accountant               311
# Developer                300
# Software Engineer        205
# Tax Professional         180
# Account Executive        147
# Data Scientist           124
# Financial Analyst        101
# Banker                    53
# Data Engineer             53
# Dental Hygienist          45
# Veterinarian              42
# UI/UX Designer            42
# Nursing Assistant         40
# Database Management       35
# Dental Assistant          24
# Veterinary Technician     17
# Veterinary Assistant      16
# Portfolio Manager         13
# Dentist                    7
# Retirement Specialist      7
# Name: title, dtype: int64

# %% [markdown]
# ## **Distribution of location in the obtained dataset**

# %%
df['location'].value_counts()
# Out:
# California        300
# Texas             220
# New York          212
# Florida           173
# Washington        122
# Illinois          108
# Massachusetts     105
# Georgia            98
# Virginia           97
# North Carolina     91
# Ohio               81
# Arizona            76
# Pennsylvania       69
# Michigan           67
# Maryland           66
# Colorado           63
# New Jersey         63
# Tennessee          42
# Connecticut        41
# Missouri           40
# South Carolina     36
# Wisconsin          32
# Indiana            31
# Oregon             29
# Kansas             29
# Kentucky           27
# Minnesota          25
# Iowa               21
# Utah               21
# Oklahoma           20
# Idaho              18
# Nebraska           16
# Maine              16
# Alabama            14
# Nevada             13
# Delaware           13
# New Hampshire      11
# Louisiana          10
# Arkansas           10
# Alaska              8
# New Mexico          8
# West Virginia       7
# Rhode Island        6
# North Dakota        5
# Hawaii              5
# Montana             4
# Vermont             4
# South Dakota        3
# Mississippi         2
# Wyoming             1
# Name: location, dtype: int64

# %% [markdown]
# ## **Distribution of experience level in the obtained dataset**

# %%
df['formatted_experience_level'].value_counts()
# Out:
# Senior          1685
# Beginner         616
# Intermediate     278
# Name: formatted_experience_level, dtype: int64

# %% [markdown]
# ## **Distribution of work type in the obtained dataset**

# %%
df['formatted_work_type'].value_counts()
# Out:
# Full-time     1986
# Contract       297
# Part-time      278
# Internship      10
# Temporary        8
# Name: formatted_work_type, dtype: int64

# %% [markdown]
# # **Renaming columns**

# %%
df.rename(columns = {"title":"job_title"}, inplace = True)
df.rename(columns = {"description":"job_desc"}, inplace = True)
df.rename(columns = {"formatted_work_type":"work_type"}, inplace = True)
df.rename(columns = {"formatted_experience_level":"experience_level"}, inplace = True)

# %% [markdown]
# # **Rearranging columns**

# %%
df.columns
# Out:
# Index(['job_id', 'job_title', 'job_desc', 'work_type', 'location',
#        'job_posting_url', 'experience_level', 'industry'],
#       dtype='object')

# %%
columns= ['job_id','job_title','job_desc','experience_level','work_type','location','industry','job_posting_url' ]

# %%
df=df[columns]

# %% [markdown]
# # **Saving to csv file**

# %%
df.to_csv('linkedin_jobs.csv',index=False)
